# %%
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_24888\2800890606.py:120: UserWarning: Glyph 30697 (\N{CJK UNIFIED IDEOGRAPH-77E9}) missing from font(s) DejaVu Sans.
#   anim = FuncAnimation(self.fig, self.update, frames=frames,
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_24888\2800890606.py:120: UserWarning: Glyph 38499 (\N{CJK UNIFIED IDEOGRAPH-9663}) missing from font(s) DejaVu Sans.
#   anim = FuncAnimation(self.fig, self.update, frames=frames,
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_24888\2800890606.py:120: UserWarning: Glyph 32080 (\N{CJK UNIFIED IDEOGRAPH-7D50}) missing from font(s) DejaVu Sans.
#   anim = FuncAnimation(self.fig, self.update, frames=frames,
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_24888\2800890606.py:120: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from font(s) DejaVu Sans.
#   anim = FuncAnimation(self.fig, self.update, frames=frames,
# ...
